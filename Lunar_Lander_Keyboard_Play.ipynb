# %% [markdown]
# # Game Instructions
# ***
# This code will start the keyboard agent gameplay to play the `Lunar Lander V2` game using the keyboard. Here are the instructions on how to play the game:<br>
# - Press Key `1` to fire off the `Right` engine to move `Left`
# - Press Key `2` to fire off the `Main` engine to move `Up`
# - Press Key `3` to fire off the `Left` engine `Right`

# %%
### IMPORT ALL LIBRARIES AND FUNCTIONS TO BE USED ###
import gym
import os

# %%
print(gym.__version__) # Print GYM VERSION and ensure its > 0.15.4
# Out:
# 0.15.4

# %%
# Change the directory to gym so we can run the keyboard agent
ROOT_PATH = os.getcwd() # get present working directory
os.chdir(os.path.join(ROOT_PATH, "gym")) # change the directory inside the gym folder
print(os.getcwd()) # show the
# Out:
# C:\Users\Admin\Documents\UFT AI\Final Project RL\gym

# %%
# !python examples/agents/keyboard_agent.py LunarLander-v2 # Start rendering the environment and start the game
# Out:
# observations: -0.01 +1.42 -0.75 +0.25 +0.02 +0.14 +0.00 +0.00
# step 0 total_reward +0.37
# observations: -0.15 +1.41 -0.67 -0.28 -0.11 -0.18 +0.00 +0.00
# step 20 total_reward -2.57
# observations: -0.29 +1.16 -0.69 -0.81 -0.25 -0.10 +0.00 +0.00
# step 40 total_reward -27.74
# observations: -0.41 +0.76 -0.40 -0.76 -0.35 -0.10 +0.00 +0.00
# step 60 total_reward +11.63
# observations: -0.45 +0.47 -0.01 -0.55 -0.44 -0.07 +0.00 +0.00
# step 80 total_reward +48.49
# observations: -0.42 +0.24 +0.42 -0.43 -0.42 +0.09 +0.00 +0.00
# step 100 total_reward +58.28
# observations: -0.30 +0.09 +0.75 -0.21 -0.24 +0.23 +0.00 +0.00
# step 120 total_reward +70.23
# observations: -0.12 +0.05 +0.88 -0.04 -0.01 +0.21 +0.00 +0.00
# step 140 total_reward +96.07
# observations: +0.05 +0.00 +0.84 -0.10 +0.02 -0.53 +0.00 +0.00
# step 160 total_reward +104.36
# observations: +0.19 +0.02 +0.63 +0.07 +0.13 +0.26 +0.00 +0.00
# step 180 total_reward +99.17
# ...
