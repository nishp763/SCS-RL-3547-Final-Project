# %% [markdown]
# # Game Instructions
# ***
# This code will start the keyboard agent gameplay to play the `Lunar Lander V2` game using the keyboard. Here are the instructions on how to play the game:<br>
# - Press Key `1` to fire off the `Left` engine
# - Press Key `2` to fire off the `Main` engine
# - Press Key `3` to fire off the `Right` engine

# %%
### IMPORT ALL LIBRARIES AND FUNCTIONS TO BE USED ###
import gym
import os

# %%
print(gym.__version__) # Print GYM VERSION and ensure its > 0.15.4
# Out:
# 0.15.4

# %%
# Change the directory to gym so we can run the keyboard agent
ROOT_PATH = os.getcwd() # get present working directory
os.chdir(os.path.join(ROOT_PATH, "gym")) # change the directory inside the gym folder
print(os.getcwd()) # show the
# Out:
# C:\Users\Admin\Documents\UFT AI\Final Project RL\gym

# %%
# !python examples/agents/keyboard_agent.py LunarLander-v2 # Start rendering the environment and start the game
# Out:
# ACTIONS=4
# Press keys 1 2 3 ... to take actions 1 2 3 ...
# No keys pressed is taking action 0
# reward -1.122
# reward -1.236
# reward -1.216
# reward -1.195
# reward -1.172
# reward -1.147
# reward -1.120
# reward -1.090
# reward -1.059
# reward -1.026
# reward -0.992
# reward -0.956
# reward -0.919
# reward -0.882
# reward -0.843
# reward -0.803
# reward -0.763
# reward -0.722
# reward -0.681
# reward -0.639
# reward -0.598
# reward -0.556
# reward -0.514
# reward -0.472
# reward -0.506
# reward -0.388
# reward -0.348
# reward -0.309
# reward -0.271
# reward -0.234
# reward -0.200
# reward -0.168
# reward -0.139
# reward -0.114
# reward -0.093
# reward -0.078
# reward -0.070
# reward -0.072
# reward -0.084
# reward -0.112
# reward 4.114
# reward 3.660
# reward 2.137
# reward 3.856
# reward 0.399
# reward 1.474
# reward -0.709
# reward -0.656
# reward -0.826
# reward -1.131
# reward -1.368
# reward -1.593
# reward -1.953
# reward 7.736
# reward -100.000
# timesteps 55 reward -109.77
# reward 0.185
# reward 0.253
# reward 0.297
# reward -0.573
# reward -0.596
# reward -0.616
# reward 0.099
# reward 0.442
# reward 1.701
# reward 0.948
# reward -0.780
# reward -0.924
# reward 0.610
# reward 0.215
# reward -1.578
# reward -0.405
# reward -0.439
# reward -0.472
# reward -0.504
# reward -0.534
# reward -0.563
# reward -0.590
# reward -1.386
# reward 0.898
# reward -1.420
# reward 0.757
# reward 0.523
# reward -1.744
# reward -2.178
# reward -0.347
# reward -0.476
# reward -0.507
# reward -0.537
# reward -0.568
# reward 0.340
# reward 0.729
# reward 0.823
# reward 1.223
# reward 1.225
# reward 1.326
# reward 1.436
# reward 1.872
# reward 1.718
# reward 1.787
# reward 2.301
# reward 1.680
# reward -2.218
# reward -2.304
# reward -2.631
# reward 0.884
# reward -0.844
# reward -1.317
# reward 2.235
# reward 1.710
# reward 0.415
# reward 0.562
# reward -1.470
# reward -0.633
# reward 0.241
# reward -1.368
# reward 2.136
# reward 2.638
# reward 0.843
# reward 0.899
# reward -0.472
# reward 2.751
# reward 2.687
# reward 0.653
# reward -3.795
# reward -3.891
# reward -4.195
# reward -3.888
# reward -3.667
# reward -3.373
# reward -3.115
# reward -2.867
# reward -2.632
# reward -2.328
# reward -2.091
# reward -1.847
# reward -1.624
# reward -1.273
# reward -1.084
# reward -0.848
# reward -0.613
# reward -0.274
# reward -0.101
# reward 0.075
# reward 0.258
# reward 0.562
# reward 0.814
# reward 0.921
# reward 7.702
# reward 6.529
# reward 3.173
# reward 7.374
# reward 4.785
# reward 4.649
# reward 4.359
# reward 4.328
# reward 7.124
# reward 2.962
# reward 5.633
# reward 4.653
# reward 4.936
# reward 3.037
# reward 2.933
# reward 4.502
# reward 3.296
# reward 3.566
# reward 2.910
# reward 4.995
# reward 5.652
# reward 2.058
# reward 3.120
# reward 5.572
# reward 5.404
# reward 2.190
# reward 3.224
# reward 3.442
# reward 0.417
# reward -0.166
# reward -4.043
# reward -3.764
# reward -3.499
# reward -3.301
# reward -2.960
# reward -2.657
# reward -2.382
# reward -2.240
# reward -1.931
# reward -1.799
# reward -1.511
# reward -1.390
# reward 1.641
# reward 1.151
# reward 0.352
# reward 1.004
# reward 5.262
# reward 3.909
# reward -1.352
# reward -1.087
# reward -0.944
# reward -0.842
# reward -0.636
# reward -1.298
# reward -3.463
# reward -3.672
# reward -3.813
# reward -4.179
# reward -4.479
# reward -3.950
# reward -4.010
# reward -4.875
# reward -5.043
# reward -5.294
# reward -5.641
# reward -5.169
# reward 4.713
# reward 13.415
# reward -100.000
# timesteps 161 reward -65.24
# reward -1.752
# reward -1.797
# reward -1.735
# reward -1.675
# reward -1.615
# reward -1.556
# reward -1.496
# reward -1.436
# reward -1.376
# reward -1.316
# reward -1.256
# reward -1.196
# reward -1.136
# reward -1.076
