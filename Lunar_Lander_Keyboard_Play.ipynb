# %%
### IMPORT ALL LIBRARIES AND FUNCTIONS TO BE USED ###
import gym
import os

# %%
print(gym.__version__) # Print GYM VERSION and ensure its > 0.15.4
# Out:
# 0.15.4

# %%
ROOT_PATH = os.getcwd()
os.chdir(os.path.join(ROOT_PATH, "gym"))
print(os.getcwd())
# Out:
# C:\Users\Admin\Documents\UFT AI\Final Project RL\gym

# %%
# !python examples/agents/keyboard_agent.py LunarLander-v2
# Out:
# ACTIONS=4
# Press keys 1 2 3 ... to take actions 1 2 3 ...
# No keys pressed is taking action 0
# reward 1.658
# reward 1.806
# reward 1.869
# reward 1.926
# reward 1.982
# reward 2.037
# reward 2.091
# reward 2.142
# reward 2.189
# reward 2.228
# reward 2.255
# reward 2.256
# reward 2.196
# reward 1.967
# reward 1.240
# reward -0.301
# reward -1.601
# reward -2.102
# reward -2.252
# reward -2.285
# reward -2.273
# reward -2.241
# reward -2.198
# reward -2.150
# reward -2.190
# reward -2.041
# reward -1.986
# reward -1.929
# reward 0.866
# reward 3.591
# reward 2.706
# reward 3.407
# reward -2.001
# reward -1.951
# reward -1.898
# reward -1.843
# reward -1.788
# reward -1.731
# reward 3.563
# reward 1.599
# reward 3.168
# reward 1.078
# reward -1.777
# reward -1.723
# reward -1.668
# reward -1.613
# reward -1.556
# reward -1.499
# reward -1.442
# reward -1.384
# reward -1.326
# reward 3.607
# reward 1.462
# reward 3.233
# reward 2.157
# reward 0.762
# reward 4.756
# reward 4.295
# reward 1.586
# reward 4.938
# reward 4.632
# reward -1.870
# reward -1.817
# reward -1.763
# reward -1.707
# reward -1.651
# reward -1.594
# reward -1.537
# reward -1.479
# reward -1.421
# reward -1.363
# reward -1.305
# reward -1.246
# reward 3.031
# reward 2.841
# reward 2.109
# reward 1.374
# reward 4.650
# reward 3.575
# reward 4.088
# reward 3.713
# reward -1.830
# reward -1.770
# reward -1.710
# reward -1.650
# reward -1.591
# reward -1.531
# reward 0.467
# reward 1.512
# reward 3.080
# reward 1.765
# reward -1.501
# reward -1.442
# reward -1.382
# reward -1.322
# reward -1.262
# reward -1.203
# reward -1.143
# reward -1.083
# reward -1.024
# reward -0.964
# reward -0.905
# reward -0.845
# reward -0.786
# reward 3.012
# reward 5.331
# reward 3.630
# reward 4.298
# reward 4.925
# reward 4.542
# reward 4.949
# reward 0.999
# reward 1.233
# reward -0.935
# reward -0.881
# reward -0.827
# reward -0.775
# reward -0.723
# reward -0.674
# reward -0.627
# reward -0.583
# reward -0.545
# reward -0.238
# reward -0.035
# reward 0.135
# reward 0.386
# reward 0.397
# reward 0.405
# reward 0.169
# reward -0.595
# reward 22.657
# reward -100.000
# timesteps 132 reward -31.37
# reward 0.465
# reward 0.403
# reward 0.324
# reward 0.233
# reward 0.130
# reward 0.017
# reward -0.104
# reward -0.231
# reward -0.362
# reward -0.494
# reward -0.623
# reward -0.748
# reward -0.865
# reward -0.974
# reward 0.206
# reward 0.238
# reward 0.460
# reward 0.283
# reward 0.285
# reward 0.499
# reward 0.734
# reward 0.511
# reward 0.592
# reward -1.801
# reward -2.651
# reward -3.172
# reward -3.146
# reward -3.116
# reward 0.919
# reward -0.775
# reward 0.871
# reward 2.276
# reward 2.169
# reward 1.681
# reward 2.248
# reward 3.169
# reward -0.115
# reward 1.509
# reward -0.229
# reward -1.484
# reward -1.136
# reward 0.415
# reward 1.129
# reward -3.815
# reward -3.758
# reward -3.700
# reward -3.642
# reward -3.584
# reward -3.525
# reward -3.467
# reward -3.408
# reward -3.350
# reward 1.033
# reward -0.356
# reward 1.177
# reward -1.541
# reward -1.385
# reward -2.261
# reward -2.166
# reward -2.425
# reward -3.324
# reward -3.370
# reward -2.267
# reward -2.157
# reward -1.910
# reward -1.561
# reward -1.156
# reward -0.959
# reward -0.945
# reward -0.713
# reward -1.261
# reward -1.215
# reward -0.352
# reward -0.164
# reward 0.026
# reward 0.492
# reward 0.731
# reward 0.927
# reward 1.011
# reward 1.350
# reward 1.515
# reward 2.028
# reward 2.030
# reward 2.483
# reward 2.759
# reward 2.242
# reward 2.299
# reward 6.851
# reward 5.488
# reward 5.700
# reward 5.997
# reward 5.620
# reward 4.964
# reward 5.428
# reward 4.605
# reward 3.905
# reward 2.473
# reward 2.050
# reward 2.088
# reward 2.128
# reward 2.167
# reward 2.208
# reward 2.248
# reward 1.386
# reward 1.320
# reward 1.048
# reward 0.989
# reward 1.031
# reward 0.694
# reward 0.650
# reward 0.385
# reward 0.004
# reward -0.527
# reward -1.310
# reward 7.173
# reward 11.895
# reward -100.000
# timesteps 117 reward -53.24
# reward -0.003
# reward -0.035
# reward -0.053
# reward -0.079
# reward -0.110
# reward -0.145
# reward -0.186
# reward -0.230
# reward -0.280
# reward -0.333
# reward -0.389
# reward -0.449
# reward -0.511
# reward -0.575
# reward -0.640
# reward -0.705
# reward -0.769
# reward -0.832
# reward -0.893
# reward -0.952
# reward -1.007
# reward -1.059
# reward -1.106
